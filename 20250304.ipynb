# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sunset = plt.imread('datasets/sunset.png') #Carga la imagen desde el archivo especificado.
plt.imshow(sunset);

# %%
type(sunset)
# Out:
# numpy.ndarray

# %%
sunset.shape
# Out:
# (600, 800, 4)

# %%
sunset.min()
# Out:
# 0.0

# %%
sunset.max()
# Out:
# 1.0

# %%
plt.hist(sunset.flatten(), bins = 50);

# %%
sunset.size #obtener el numero total de todas dimensiones
# Out:
# 1920000

# %%
plt.hist(sunset[:, :, 0:3].flatten(), bins = 100);

# %%
plt.hist(sunset[:, :, -1].flatten(), bins = 100);

# %%
sunset[100,100,:3] = 1

# %%
plt.imshow(sunset);

# %%
sunset[100,:,:3] = 1

# %%
plt.imshow(sunset);

# %%
sunset[200:400,100:700,-1] = 0.5

# %%
plt.imshow(sunset);

# %%
sun = sunset[490:520,470:480,:] #los puntos de la derecha se podrían omitir.
plt.imshow(sun);

# %% [markdown]
# ## Vistas y copias

# %%
a = np.arange(100,109).reshape(3,3)
a
# Out:
# array([[100, 101, 102],
#        [103, 104, 105],
#        [106, 107, 108]])

# %%
a * 2 #aqui no estamos modificando nada porque a sigue siendo la primera
# Out:
# array([[200, 202, 204],
#        [206, 208, 210],
#        [212, 214, 216]])

# %%
b = a[:2,1] #cuando hacemos slicing perdemos lo que está en a, modificamos A

# %%
b
# Out:
# array([101, 104])

# %%
b[0] = -1

# %%
a
# Out:
# array([[100,  -1, 102],
#        [103, 104, 105],
#        [106, 107, 108]])

# %%
a.flatten()
# Out:
# array([100,  -1, 102, 103, 104, 105, 106, 107, 108])
